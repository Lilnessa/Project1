# %% [markdown]
# ### **Project 1** - San Diego Gas Prices
# #### Vanessa Dumlao, Shruti Palur Mallampalli, Noelle Watson

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from config import numbeo_api

# %%
# Pull in gas prices csv
gas_prices_data = pd.read_csv("Resources/gas-prices_2023-10-02.csv")
gas_prices_data.head()
# Out:
#                 title                                          address  \
# 0  Fashion Valley Gas              6899 Friars Rd, San Diego, CA 92108
# 1               Shell       2777 Health Center Dr, San Diego, CA 92123
# 2               Mobil  10496 Clairemont Mesa Blvd, San Diego, CA 92124
# 3               Shell            2521 Pacific Hwy, San Diego, CA 92101
# 4               Shell            3901 Governor Dr, San Diego, CA 92122
#
#   gasPrices/0/currency gasPrices/0/gasType  gasPrices/0/price  \
# 0                  USD             Regular               6.40
# 1                  USD             Regular               7.01
# 2                  USD             Regular               6.00
# 3                  USD             Regular               7.00
# 4                  USD             Regular               6.30
#
#   gasPrices/0/priceTag gasPrices/0/unit     gasPrices/0/updatedAt  \
# 0                $6.40           gallon  2023-10-02T08:50:29.000Z
# 1                $7.01           gallon  2023-10-02T11:26:11.000Z
# 2                $6.00           gallon  2023-10-02T13:00:11.000Z
# 3                $7.00           gallon  2023-10-02T15:21:32.000Z
# 4                $6.30           gallon  2023-10-02T07:57:52.000Z
#
#   gasPrices/1/currency gasPrices/1/gasType  ...     gasPrices/3/updatedAt  \
# 0                  USD            Midgrade  ...                       NaN
# 1                  USD            Midgrade  ...  2023-10-01T00:30:12.000Z
# 2                  USD            Midgrade  ...  2023-10-02T10:05:01.000Z
# 3                  USD            Midgrade  ...                       NaN
# 4                  USD            Midgrade  ...                       NaN
#
#                                              website           phone  \
# 0                                                NaN  (619) 295-1169
# 1  https://find.shell.com/us/fuel/12476277-2777-h...  (859) 279-3673
# 2  https://www.exxon.com/en/find-station/MOBIL-SA...  (858) 565-1627
# 3  https://find.shell.com/us/fuel/10008237-2521-p...  (619) 233-4120
# 4  https://find.shell.com/us/fuel/10087441-3901-g...  (858) 453-0676
#
#   totalScore rank reviewsCount  isAdvertisement categoryName  \
# 0        4.2    2          136            False  Gas station
# 1        3.5    3           40            False  Gas station
# 2        4.3    7           65            False  Gas station
# 3        3.3    8           94            False  Gas station
# 4        3.3   20           44            False  Gas station
#
#                searchString                                                url
# 0  gas station in San Diego  https://www.google.com/maps/place/Fashion+Vall...
# 1  gas station in San Diego  https://www.google.com/maps/place/Shell/@32.79...
# 2  gas station in San Diego  https://www.google.com/maps/place/Mobil/@32.82...
# 3  gas station in San Diego  https://www.google.com/maps/place/Shell/@32.72...
# 4  gas station in San Diego  https://www.google.com/maps/place/Shell/@32.85...
#
# [5 rows x 35 columns]

# %%
# Parse out zip code
gas_prices_data['zip code'] = gas_prices_data['address'].str.split().str[-1]
gas_prices_data.head()
# Out:
#                 title                                          address  \
# 0  Fashion Valley Gas              6899 Friars Rd, San Diego, CA 92108
# 1               Shell       2777 Health Center Dr, San Diego, CA 92123
# 2               Mobil  10496 Clairemont Mesa Blvd, San Diego, CA 92124
# 3               Shell            2521 Pacific Hwy, San Diego, CA 92101
# 4               Shell            3901 Governor Dr, San Diego, CA 92122
#
#   gasPrices/0/currency gasPrices/0/gasType  gasPrices/0/price  \
# 0                  USD             Regular               6.40
# 1                  USD             Regular               7.01
# 2                  USD             Regular               6.00
# 3                  USD             Regular               7.00
# 4                  USD             Regular               6.30
#
#   gasPrices/0/priceTag gasPrices/0/unit     gasPrices/0/updatedAt  \
# 0                $6.40           gallon  2023-10-02T08:50:29.000Z
# 1                $7.01           gallon  2023-10-02T11:26:11.000Z
# 2                $6.00           gallon  2023-10-02T13:00:11.000Z
# 3                $7.00           gallon  2023-10-02T15:21:32.000Z
# 4                $6.30           gallon  2023-10-02T07:57:52.000Z
#
#   gasPrices/1/currency gasPrices/1/gasType  ...  \
# 0                  USD            Midgrade  ...
# 1                  USD            Midgrade  ...
# 2                  USD            Midgrade  ...
# 3                  USD            Midgrade  ...
# 4                  USD            Midgrade  ...
#
#                                              website           phone  \
# 0                                                NaN  (619) 295-1169
# 1  https://find.shell.com/us/fuel/12476277-2777-h...  (859) 279-3673
# 2  https://www.exxon.com/en/find-station/MOBIL-SA...  (858) 565-1627
# 3  https://find.shell.com/us/fuel/10008237-2521-p...  (619) 233-4120
# 4  https://find.shell.com/us/fuel/10087441-3901-g...  (858) 453-0676
#
#   totalScore rank reviewsCount isAdvertisement  categoryName  \
# 0        4.2    2          136           False   Gas station
# 1        3.5    3           40           False   Gas station
# 2        4.3    7           65           False   Gas station
# 3        3.3    8           94           False   Gas station
# 4        3.3   20           44           False   Gas station
#
#                searchString  \
# 0  gas station in San Diego
# 1  gas station in San Diego
# 2  gas station in San Diego
# 3  gas station in San Diego
# 4  gas station in San Diego
#
#                                                  url zip code
# 0  https://www.google.com/maps/place/Fashion+Vall...    92108
# 1  https://www.google.com/maps/place/Shell/@32.79...    92123
# 2  https://www.google.com/maps/place/Mobil/@32.82...    92124
# 3  https://www.google.com/maps/place/Shell/@32.72...    92101
# 4  https://www.google.com/maps/place/Shell/@32.85...    92122
#
# [5 rows x 36 columns]

# %%
# Rename Columns
gas_prices_data_df = gas_prices_data.rename(columns={"title" : "business",
                                "gasPrices/0/currency" : "gas1 currency",
                                "gasPrices/0/gasType" : "gas1 type",
                                "gasPrices/0/price": "gas1 price",
                                "gasPrices/0/priceTag" : "gas1 pricetag",
                                "gasPrices/0/unit": "gas1 unit",
                                "gasPrices/0/updatedAt" : "gas1 updated",
                                "gasPrices/1/currency" : "gas2 currency",
                                "gasPrices/1/gasType": "gas2 type",
                                "gasPrices/1/price": "gas2 price",
                                "gasPrices/1/priceTag": "gas2 pricetag",
                                "gasPrices/1/unit": "gas2 unit",
                                "gasPrices/1/updatedAt" : "gas2 updated",
                                "gasPrices/2/currency" : "gas3 currency",
                                "gasPrices/2/gasType": "gas3 type",
                                "gasPrices/2/price": "gas3 price",
                                "gasPrices/2/priceTag": "gas3 pricetag",
                                "gasPrices/2/unit": "gas3 unit",
                                "gasPrices/2/updatedAt": "gas3 updated",
                                "gasPrices/3/currency": "gas4 currency",
                                "gasPrices/3/gasType": "gas4 type",
                                "gasPrices/3/price": "gas4 price",
                                "gasPrices/3/priceTag": "gas4 pricetag",
                                "gasPrices/3/unit" :"gas4 unit",
                                "gasPrices/3/updatedAt" : "gas4 updated"
    
})

# %%
gas_prices_data_df.head()
# Out:
#              business                                          address  \
# 0  Fashion Valley Gas              6899 Friars Rd, San Diego, CA 92108
# 1               Shell       2777 Health Center Dr, San Diego, CA 92123
# 2               Mobil  10496 Clairemont Mesa Blvd, San Diego, CA 92124
# 3               Shell            2521 Pacific Hwy, San Diego, CA 92101
# 4               Shell            3901 Governor Dr, San Diego, CA 92122
#
#   gas1 currency gas1 type  gas1 price gas1 pricetag gas1 unit  \
# 0           USD   Regular        6.40         $6.40    gallon
# 1           USD   Regular        7.01         $7.01    gallon
# 2           USD   Regular        6.00         $6.00    gallon
# 3           USD   Regular        7.00         $7.00    gallon
# 4           USD   Regular        6.30         $6.30    gallon
#
#                gas1 updated gas2 currency gas2 type  ...  \
# 0  2023-10-02T08:50:29.000Z           USD  Midgrade  ...
# 1  2023-10-02T11:26:11.000Z           USD  Midgrade  ...
# 2  2023-10-02T13:00:11.000Z           USD  Midgrade  ...
# 3  2023-10-02T15:21:32.000Z           USD  Midgrade  ...
# 4  2023-10-02T07:57:52.000Z           USD  Midgrade  ...
#
#                                              website           phone  \
# 0                                                NaN  (619) 295-1169
# 1  https://find.shell.com/us/fuel/12476277-2777-h...  (859) 279-3673
# 2  https://www.exxon.com/en/find-station/MOBIL-SA...  (858) 565-1627
# 3  https://find.shell.com/us/fuel/10008237-2521-p...  (619) 233-4120
# 4  https://find.shell.com/us/fuel/10087441-3901-g...  (858) 453-0676
#
#   totalScore rank reviewsCount isAdvertisement  categoryName  \
# 0        4.2    2          136           False   Gas station
# 1        3.5    3           40           False   Gas station
# 2        4.3    7           65           False   Gas station
# 3        3.3    8           94           False   Gas station
# 4        3.3   20           44           False   Gas station
#
#                searchString  \
# 0  gas station in San Diego
# 1  gas station in San Diego
# 2  gas station in San Diego
# 3  gas station in San Diego
# 4  gas station in San Diego
#
#                                                  url zip code
# 0  https://www.google.com/maps/place/Fashion+Vall...    92108
# 1  https://www.google.com/maps/place/Shell/@32.79...    92123
# 2  https://www.google.com/maps/place/Mobil/@32.82...    92124
# 3  https://www.google.com/maps/place/Shell/@32.72...    92101
# 4  https://www.google.com/maps/place/Shell/@32.85...    92122
#
# [5 rows x 36 columns]

# %%
gas_prices_data_df.columns.tolist()
# Out:
# ['business',
#  'address',
#  'gas1 currency',
#  'gas1 type',
#  'gas1 price',
#  'gas1 pricetag',
#  'gas1 unit',
#  'gas1 updated',
#  'gas2 currency',
#  'gas2 type',
#  'gas2 price',
#  'gas2 pricetag',
#  'gas2 unit',
#  'gas2 updated',
#  'gas3 currency',
#  'gas3 type',
#  'gas3 price',
#  'gas3 pricetag',
#  'gas3 unit',
#  'gas3 updated',
#  'gas4 currency',
#  'gas4 type',
#  'gas4 price',
#  'gas4 pricetag',
#  'gas4 unit',
#  'gas4 updated',
#  'website',
#  'phone',
#  'totalScore',
#  'rank',
#  'reviewsCount',
#  'isAdvertisement',
#  'categoryName',
#  'searchString',
#  'url',
#  'zip code']

# %%
cleaned_gas_df = gas_prices_data_df[["business", "zip code", "address", "gas1 currency", "gas1 type", "gas1 price", "gas1 pricetag", "gas1 unit", "gas1 updated",
                                    "gas2 currency", "gas2 type", "gas2 price", "gas2 pricetag", "gas2 unit", "gas2 updated",
                                    "gas3 currency", "gas3 type", "gas3 price", "gas3 pricetag", "gas3 unit", "gas3 updated"]].copy()

# %%
cleaned_gas_df.head()
# Out:
#              business zip code  \
# 0  Fashion Valley Gas    92108
# 1               Shell    92123
# 2               Mobil    92124
# 3               Shell    92101
# 4               Shell    92122
#
#                                            address gas1 currency gas1 type  \
# 0              6899 Friars Rd, San Diego, CA 92108           USD   Regular
# 1       2777 Health Center Dr, San Diego, CA 92123           USD   Regular
# 2  10496 Clairemont Mesa Blvd, San Diego, CA 92124           USD   Regular
# 3            2521 Pacific Hwy, San Diego, CA 92101           USD   Regular
# 4            3901 Governor Dr, San Diego, CA 92122           USD   Regular
#
#    gas1 price gas1 pricetag gas1 unit              gas1 updated gas2 currency  \
# 0        6.40         $6.40    gallon  2023-10-02T08:50:29.000Z           USD
# 1        7.01         $7.01    gallon  2023-10-02T11:26:11.000Z           USD
# 2        6.00         $6.00    gallon  2023-10-02T13:00:11.000Z           USD
# 3        7.00         $7.00    gallon  2023-10-02T15:21:32.000Z           USD
# 4        6.30         $6.30    gallon  2023-10-02T07:57:52.000Z           USD
#
#    ... gas2 price  gas2 pricetag gas2 unit              gas2 updated  \
# 0  ...        6.5          $6.50    gallon  2023-10-01T18:08:43.000Z
# 1  ...        7.2          $7.20    gallon  2023-10-02T12:03:22.000Z
# 2  ...        6.4          $6.40    gallon  2023-10-01T13:35:00.000Z
# 3  ...        7.2          $7.20    gallon  2023-09-30T10:30:08.000Z
# 4  ...        6.5          $6.50    gallon  2023-10-01T15:11:50.000Z
#
#   gas3 currency gas3 type gas3 price  gas3 pricetag gas3 unit  \
# 0           USD   Premium       6.60          $6.60    gallon
# 1           USD   Premium       6.60          $6.60    gallon
# 2           USD   Premium       6.40          $6.40    gallon
# 3           USD   Premium       7.30          $7.30    gallon
# 4           USD   Premium       6.66          $6.66    gallon
#
#                gas3 updated
# 0  2023-09-30T16:48:07.000Z
# 1  2023-10-02T09:14:17.000Z
# 2  2023-10-02T09:19:29.000Z
# 3  2023-10-02T15:17:31.000Z
# 4  2023-10-02T07:24:18.000Z
#
# [5 rows x 21 columns]

# %%
cleaned_gas_df.count()
# Out:
# business         102
# zip code         102
# address          102
# gas1 currency     85
# gas1 type         85
# gas1 price        85
# gas1 pricetag     85
# gas1 unit         85
# gas1 updated      85
# gas2 currency     85
# gas2 type         85
# gas2 price        85
# gas2 pricetag     85
# gas2 unit         85
# gas2 updated      85
# gas3 currency     85
# gas3 type         85
# gas3 price        85
# gas3 pricetag     85
# gas3 unit         85
# gas3 updated      85
# dtype: int64

# %%
extra_clean_gas = cleaned_gas_df.dropna()
extra_clean_gas.count()
# Out:
# business         85
# zip code         85
# address          85
# gas1 currency    85
# gas1 type        85
# gas1 price       85
# gas1 pricetag    85
# gas1 unit        85
# gas1 updated     85
# gas2 currency    85
# gas2 type        85
# gas2 price       85
# gas2 pricetag    85
# gas2 unit        85
# gas2 updated     85
# gas3 currency    85
# gas3 type        85
# gas3 price       85
# gas3 pricetag    85
# gas3 unit        85
# gas3 updated     85
# dtype: int64

# %%
print(extra_clean_gas['gas1 currency'].unique())
print(extra_clean_gas['gas1 type'].unique())
print(extra_clean_gas['gas1 unit'].unique())
print(extra_clean_gas['gas2 currency'].unique())
print(extra_clean_gas['gas2 type'].unique())
print(extra_clean_gas['gas2 unit'].unique())
print(extra_clean_gas['gas3 currency'].unique())
print(extra_clean_gas['gas3 type'].unique())
print(extra_clean_gas['gas3 unit'].unique())
# Out:
# ['USD']
# ['Regular']
# ['gallon']
# ['USD']
# ['Midgrade']
# ['gallon']
# ['USD']
# ['Premium']
# ['gallon']

# %%
# Read in CSV and clean data
SD_median_income = pd.read_csv("Resources/Household Income Median.csv")
SD_median_income = SD_median_income.rename(columns={'Zip':'zip code'})
SD_median_income = SD_median_income.dropna()
SD_median_income.head()
# Out:
#   zip code  Household Income Median
# 0    92014                 155531.0
# 1    92025                  58273.0
# 2    92027                  65989.0
# 3    92037                 109194.0
# 4    92071                  87334.0

# %%
# Find unique number of zipcodes in income dataset
SD_median_income['zip code'].unique().size
# Out:
# 37

# %%
# Find unique number of zipcodes in gas dataset
extra_clean_gas['zip code'].unique().size
# Out:
# 23

# %%
# Calculate average gas prices per zip code
averaged_gas1_prices = extra_clean_gas.groupby(["zip code"])["gas1 price"].mean()
averaged_gas2_prices = extra_clean_gas.groupby(["zip code"])["gas2 price"].mean()
averaged_gas3_prices = extra_clean_gas.groupby(["zip code"])["gas3 price"].mean()

# %%
# Create df with avg gas prices per zip
gas_price_per_zip_avg = pd.DataFrame(
    {
        "Regular avg": averaged_gas1_prices,
        "Midgrade avg": averaged_gas2_prices,
        "Premium avg": averaged_gas3_prices,
    }
)
gas_price_per_zip_avg.head()
# Out:
#           Regular avg  Midgrade avg  Premium avg
# zip code
# 92101        6.733333      6.900000     6.950000
# 92102        6.400000      6.600000     6.725000
# 92103        6.640000      6.860000     6.980000
# 92104        6.376667      6.560000     6.758889
# 92105        6.293333      6.418333     6.671667

# %%
# Load in csv with lat, long, population, density
zip_df = pd.read_csv("Resources/uszips.csv")
sd_zip_df_unclean = zip_df.loc[zip_df["county_names_all"] == "San Diego", :]
sd_zip_df_unclean = sd_zip_df_unclean.rename(columns={'zip':'zip code'})
# Create df of only info we want
sd_zip_df = sd_zip_df_unclean[['zip code', 'lat', 'lng', 'city', 'population', 'density']]
sd_zip_df = pd.DataFrame(sd_zip_df)

sd_zip_df.head(30)
# Out:
#        zip code       lat        lng                city  population  density
# 30911     91901  32.81467 -116.71929              Alpine     18367.0     91.1
# 30912     91902  32.67479 -117.00475              Bonita     17759.0    611.3
# 30913     91905  32.67773 -116.30734           Boulevard      1616.0      7.5
# 30914     91906  32.66241 -116.47255               Campo      4547.0     16.7
# 30915     91910  32.63653 -117.06301         Chula Vista     76291.0   2340.3
# 30916     91911  32.60686 -117.04984         Chula Vista     88589.0   2687.4
# 30917     91913  32.62174 -116.98609         Chula Vista     53725.0   2280.5
# 30918     91914  32.66604 -116.95426         Chula Vista     17742.0   1031.0
# 30919     91915  32.62266 -116.95013         Chula Vista     34616.0   1729.2
# 30920     91916  32.91103 -116.63201            Descanso      1966.0     12.3
# 30921     91917  32.62670 -116.71894             Dulzura       769.0      5.7
# 30922     91931  32.83758 -116.58029              Guatay       765.0     36.0
# 30923     91932  32.56923 -117.11798      Imperial Beach     26375.0   2381.1
# 30924     91934  32.66488 -116.16828             Jacumba       796.0      6.0
# 30925     91935  32.70214 -116.78721               Jamul      9450.0     34.6
# 30926     91941  32.75964 -116.99253             La Mesa     33858.0   1589.7
# 30927     91942  32.77728 -117.02129             La Mesa     40863.0   2734.3
# 30928     91945  32.73315 -117.03402         Lemon Grove     27685.0   2704.1
# 30929     91948  32.87509 -116.47076        Mount Laguna       137.0      1.5
# 30930     91950  32.66952 -117.09313       National City     58349.0   3070.4
# 30931     91962  32.79248 -116.48044         Pine Valley      2507.0     16.5
# 30932     91963  32.64798 -116.59640             Potrero       501.0      4.7
# 30933     91977  32.72387 -116.99631       Spring Valley     65722.0   2558.6
# 30934     91978  32.71209 -116.94103       Spring Valley     10979.0    355.0
# 30935     91980  32.58685 -116.61969              Tecate         0.0      0.0
# 30936     92003  33.28701 -117.19977             Bonsall      4299.0    110.5
# 30938     92007  33.02216 -117.27389  Cardiff By The Sea     11447.0   1911.1
# 30939     92008  33.14564 -117.31691            Carlsbad     27742.0   1029.9
# 30940     92009  33.09535 -117.24574            Carlsbad     46622.0   1477.3
# 30941     92010  33.15676 -117.28423            Carlsbad     15976.0    748.4

# %%
# Making sure zip in all dfs are string types
sd_zip_df['zip code'] = sd_zip_df['zip code'].astype(int)
gas_price_per_zip_avg['zip code'] = gas_price_per_zip_avg['zip code'].astype(int)
SD_median_income['zip code'] = SD_median_income['zip code'].astype(int)

# %%
merg_zip_data = sd_zip_df.merge(gas_price_per_zip_avg, on=['zip code'], how='right')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\UCSD\class_files\7\Project1\gas_prices_zip_code.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/UCSD/class_files/7/Project1/gas_prices_zip_code.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> merg_zip_data = sd_zip_df.merge(gas_price_per_zip_avg, on=['zip code'], how='right')
#
# File c:\Users\noell\anaconda3\Lib\site-packages\pandas\core\frame.py:9843, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9824 @Substitution("")
#    9825 @Appender(_merge_doc, indents=2)
#    9826 def merge(
#    (...)
#    9839     validate: str | None = None,
#    9840 ) -> DataFrame:
#    9841     from pandas.core.reshape.merge import merge
# -> 9843     return merge(
#    9844         self,
#    9845         right,
#    9846         how=how,
#    9847         on=on,
#    9848         left_on=left_on,
#    9849         right_on=right_on,
#    9850         left_index=left_index,
#    9851         right_index=right_index,
#    9852         sort=sort,
#    9853         suffixes=suffixes,
#    9854         copy=copy,
#    9855         indicator=indicator,
#    9856         validate=validate,
#    9857     )
#
# File c:\Users\noell\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:148, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     131 @Substitution("\nleft : DataFrame or named Series")
#     132 @Appender(_merge_doc, indents=0)
#     133 def merge(
#    (...)
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
#     151         how=how,
#     152         on=on,
#     153         left_on=left_on,
#     154         right_on=right_on,
#     155         left_index=left_index,
#     156         right_index=right_index,
#     157         sort=sort,
#     158         suffixes=suffixes,
#     159         indicator=indicator,
#     160         validate=validate,
#     161     )
#     162     return op.get_result(copy=copy)
#
# File c:\Users\noell\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:741, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     733 (
#     734     self.left_join_keys,
#     735     self.right_join_keys,
#     736     self.join_names,
#     737 ) = self._get_merge_keys()
#     739 # validate the merge keys dtypes. We may need to coerce
#     740 # to avoid incompatible dtypes
# --> 741 self._maybe_coerce_merge_keys()
#     743 # If argument passed to validate,
#     744 # check if columns specified as unique
#     745 # are in fact unique.
#     746 if validate is not None:
#
# File c:\Users\noell\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:1401, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1395     # unless we are merging non-string-like with string-like
#    1396     elif (
#    1397         inferred_left in string_types and inferred_right not in string_types
#    1398     ) or (
#    1399         inferred_right in string_types and inferred_left not in string_types
#    1400     ):
# -> 1401         raise ValueError(msg)
#    1403 # datetimelikes must match exactly
#    1404 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on int64 and object columns. If you wish to proceed you should use pd.concat
