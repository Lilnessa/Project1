# %% [markdown]
# ### **Project 1** - San Diego Gas Prices
# #### Vanessa Dumlao, Shruti Palur Mallampalli, Noelle Watson

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from config import numbeo_api

# %%
# Pull in gas prices csv
gas_prices_data = pd.read_csv("Resources/gas-prices-10-04.csv")
gas_prices_data.head()
# Out:
#                          title  \
# 0                        Shell
# 1                        Shell
# 2          Texas Street Valero
# 3                      Chevron
# 4  Laurel Pacific Gas (Valero)
#
#                                           address gasPrices/0/currency  \
# 0                  1011 A St, San Diego, CA 92101                  USD
# 1      2777 Health Center Dr, San Diego, CA 92123                  USD
# 2              4616 Texas St, San Diego, CA 92116                  USD
# 3  7070 Clairemont Mesa Blvd, San Diego, CA 92117                  USD
# 4           2499 Pacific Hwy, San Diego, CA 92101                  USD
#
#   gasPrices/0/gasType  gasPrices/0/price gasPrices/0/priceTag  \
# 0             Regular                7.0                $7.00
# 1             Regular                7.0                $7.00
# 2             Regular                6.4                $6.40
# 3             Regular                6.3                $6.30
# 4             Regular                6.8                $6.80
#
#   gasPrices/0/unit     gasPrices/0/updatedAt gasPrices/1/currency  \
# 0           gallon  2023-10-03T09:20:18.000Z                  USD
# 1           gallon  2023-10-02T15:59:32.000Z                  USD
# 2           gallon  2023-10-03T05:53:19.000Z                  USD
# 3           gallon  2023-10-03T09:15:59.000Z                  USD
# 4           gallon  2023-10-03T09:17:23.000Z                  USD
#
#   gasPrices/1/gasType  ...     gasPrices/3/updatedAt  \
# 0            Midgrade  ...                       NaN
# 1            Midgrade  ...  2023-10-03T04:43:15.000Z
# 2            Midgrade  ...  2023-10-03T05:53:19.000Z
# 3            Midgrade  ...  2023-10-03T09:15:59.000Z
# 4            Midgrade  ...  2023-10-03T08:24:45.000Z
#
#                                              website           phone  \
# 0  https://find.shell.com/us/fuel/10008234-1011-a-st  (619) 232-2906
# 1  https://find.shell.com/us/fuel/12476277-2777-h...  (859) 279-3673
# 2                                                NaN  (619) 296-4913
# 3  http://www.chevronwithtechron.com/stations/sta...  (858) 922-4894
# 4  https://locations.valero.com/en-us/LocationDet...  (619) 338-4965
#
#   totalScore rank reviewsCount  isAdvertisement categoryName  \
# 0        3.3    4          124            False  Gas station
# 1        3.5    3           40            False  Gas station
# 2        4.1   37          235            False  Gas station
# 3        3.7   35           20            False  Gas station
# 4        3.7   36          147            False  Gas station
#
#                searchString                                                url
# 0  gas station in San Diego  https://www.google.com/maps/place/Shell/@32.71...
# 1  gas station in San Diego  https://www.google.com/maps/place/Shell/@32.79...
# 2  gas station in San Diego  https://www.google.com/maps/place/Texas+Street...
# 3  gas station in San Diego  https://www.google.com/maps/place/Chevron/@32....
# 4  gas station in San Diego  https://www.google.com/maps/place/Laurel+Pacif...
#
# [5 rows x 35 columns]

# %%
# Parse out zip code
gas_prices_data['zip code'] = gas_prices_data['address'].str.split().str[-1]
gas_prices_data.head()
# Out:
#                          title  \
# 0                        Shell
# 1                        Shell
# 2          Texas Street Valero
# 3                      Chevron
# 4  Laurel Pacific Gas (Valero)
#
#                                           address gasPrices/0/currency  \
# 0                  1011 A St, San Diego, CA 92101                  USD
# 1      2777 Health Center Dr, San Diego, CA 92123                  USD
# 2              4616 Texas St, San Diego, CA 92116                  USD
# 3  7070 Clairemont Mesa Blvd, San Diego, CA 92117                  USD
# 4           2499 Pacific Hwy, San Diego, CA 92101                  USD
#
#   gasPrices/0/gasType  gasPrices/0/price gasPrices/0/priceTag  \
# 0             Regular                7.0                $7.00
# 1             Regular                7.0                $7.00
# 2             Regular                6.4                $6.40
# 3             Regular                6.3                $6.30
# 4             Regular                6.8                $6.80
#
#   gasPrices/0/unit     gasPrices/0/updatedAt gasPrices/1/currency  \
# 0           gallon  2023-10-03T09:20:18.000Z                  USD
# 1           gallon  2023-10-02T15:59:32.000Z                  USD
# 2           gallon  2023-10-03T05:53:19.000Z                  USD
# 3           gallon  2023-10-03T09:15:59.000Z                  USD
# 4           gallon  2023-10-03T09:17:23.000Z                  USD
#
#   gasPrices/1/gasType  ...                                            website  \
# 0            Midgrade  ...  https://find.shell.com/us/fuel/10008234-1011-a-st
# 1            Midgrade  ...  https://find.shell.com/us/fuel/12476277-2777-h...
# 2            Midgrade  ...                                                NaN
# 3            Midgrade  ...  http://www.chevronwithtechron.com/stations/sta...
# 4            Midgrade  ...  https://locations.valero.com/en-us/LocationDet...
#
#             phone totalScore rank reviewsCount isAdvertisement  categoryName  \
# 0  (619) 232-2906        3.3    4          124           False   Gas station
# 1  (859) 279-3673        3.5    3           40           False   Gas station
# 2  (619) 296-4913        4.1   37          235           False   Gas station
# 3  (858) 922-4894        3.7   35           20           False   Gas station
# 4  (619) 338-4965        3.7   36          147           False   Gas station
#
#                searchString  \
# 0  gas station in San Diego
# 1  gas station in San Diego
# 2  gas station in San Diego
# 3  gas station in San Diego
# 4  gas station in San Diego
#
#                                                  url zip code
# 0  https://www.google.com/maps/place/Shell/@32.71...    92101
# 1  https://www.google.com/maps/place/Shell/@32.79...    92123
# 2  https://www.google.com/maps/place/Texas+Street...    92116
# 3  https://www.google.com/maps/place/Chevron/@32....    92117
# 4  https://www.google.com/maps/place/Laurel+Pacif...    92101
#
# [5 rows x 36 columns]

# %%
# Rename Columns
gas_prices_data_df = gas_prices_data.rename(columns={"title" : "business",
                                "gasPrices/0/currency" : "gas1 currency",
                                "gasPrices/0/gasType" : "gas1 type",
                                "gasPrices/0/price": "gas1 price",
                                "gasPrices/0/priceTag" : "gas1 pricetag",
                                "gasPrices/0/unit": "gas1 unit",
                                "gasPrices/0/updatedAt" : "gas1 updated",
                                "gasPrices/1/currency" : "gas2 currency",
                                "gasPrices/1/gasType": "gas2 type",
                                "gasPrices/1/price": "gas2 price",
                                "gasPrices/1/priceTag": "gas2 pricetag",
                                "gasPrices/1/unit": "gas2 unit",
                                "gasPrices/1/updatedAt" : "gas2 updated",
                                "gasPrices/2/currency" : "gas3 currency",
                                "gasPrices/2/gasType": "gas3 type",
                                "gasPrices/2/price": "gas3 price",
                                "gasPrices/2/priceTag": "gas3 pricetag",
                                "gasPrices/2/unit": "gas3 unit",
                                "gasPrices/2/updatedAt": "gas3 updated",
                                "gasPrices/3/currency": "gas4 currency",
                                "gasPrices/3/gasType": "gas4 type",
                                "gasPrices/3/price": "gas4 price",
                                "gasPrices/3/priceTag": "gas4 pricetag",
                                "gasPrices/3/unit" :"gas4 unit",
                                "gasPrices/3/updatedAt" : "gas4 updated"
    
})

# %%
gas_prices_data_df.head()
# Out:
#                       business  \
# 0                        Shell
# 1                        Shell
# 2          Texas Street Valero
# 3                      Chevron
# 4  Laurel Pacific Gas (Valero)
#
#                                           address gas1 currency gas1 type  \
# 0                  1011 A St, San Diego, CA 92101           USD   Regular
# 1      2777 Health Center Dr, San Diego, CA 92123           USD   Regular
# 2              4616 Texas St, San Diego, CA 92116           USD   Regular
# 3  7070 Clairemont Mesa Blvd, San Diego, CA 92117           USD   Regular
# 4           2499 Pacific Hwy, San Diego, CA 92101           USD   Regular
#
#    gas1 price gas1 pricetag gas1 unit              gas1 updated gas2 currency  \
# 0         7.0         $7.00    gallon  2023-10-03T09:20:18.000Z           USD
# 1         7.0         $7.00    gallon  2023-10-02T15:59:32.000Z           USD
# 2         6.4         $6.40    gallon  2023-10-03T05:53:19.000Z           USD
# 3         6.3         $6.30    gallon  2023-10-03T09:15:59.000Z           USD
# 4         6.8         $6.80    gallon  2023-10-03T09:17:23.000Z           USD
#
#   gas2 type  ...                                            website  \
# 0  Midgrade  ...  https://find.shell.com/us/fuel/10008234-1011-a-st
# 1  Midgrade  ...  https://find.shell.com/us/fuel/12476277-2777-h...
# 2  Midgrade  ...                                                NaN
# 3  Midgrade  ...  http://www.chevronwithtechron.com/stations/sta...
# 4  Midgrade  ...  https://locations.valero.com/en-us/LocationDet...
#
#             phone totalScore rank reviewsCount isAdvertisement  categoryName  \
# 0  (619) 232-2906        3.3    4          124           False   Gas station
# 1  (859) 279-3673        3.5    3           40           False   Gas station
# 2  (619) 296-4913        4.1   37          235           False   Gas station
# 3  (858) 922-4894        3.7   35           20           False   Gas station
# 4  (619) 338-4965        3.7   36          147           False   Gas station
#
#                searchString  \
# 0  gas station in San Diego
# 1  gas station in San Diego
# 2  gas station in San Diego
# 3  gas station in San Diego
# 4  gas station in San Diego
#
#                                                  url zip code
# 0  https://www.google.com/maps/place/Shell/@32.71...    92101
# 1  https://www.google.com/maps/place/Shell/@32.79...    92123
# 2  https://www.google.com/maps/place/Texas+Street...    92116
# 3  https://www.google.com/maps/place/Chevron/@32....    92117
# 4  https://www.google.com/maps/place/Laurel+Pacif...    92101
#
# [5 rows x 36 columns]

# %%
gas_prices_data_df.columns.tolist()
# Out:
# ['business',
#  'address',
#  'gas1 currency',
#  'gas1 type',
#  'gas1 price',
#  'gas1 pricetag',
#  'gas1 unit',
#  'gas1 updated',
#  'gas2 currency',
#  'gas2 type',
#  'gas2 price',
#  'gas2 pricetag',
#  'gas2 unit',
#  'gas2 updated',
#  'gas3 currency',
#  'gas3 type',
#  'gas3 price',
#  'gas3 pricetag',
#  'gas3 unit',
#  'gas3 updated',
#  'gas4 currency',
#  'gas4 type',
#  'gas4 price',
#  'gas4 pricetag',
#  'gas4 unit',
#  'gas4 updated',
#  'website',
#  'phone',
#  'totalScore',
#  'rank',
#  'reviewsCount',
#  'isAdvertisement',
#  'categoryName',
#  'searchString',
#  'url',
#  'zip code']

# %%
cleaned_gas_df = gas_prices_data_df[["business", "zip code", "address", "gas1 currency", "gas1 type", "gas1 price", "gas1 pricetag", "gas1 unit", "gas1 updated",
                                    "gas2 currency", "gas2 type", "gas2 price", "gas2 pricetag", "gas2 unit", "gas2 updated",
                                    "gas3 currency", "gas3 type", "gas3 price", "gas3 pricetag", "gas3 unit", "gas3 updated"]].copy()

# %%
cleaned_gas_df.head()
# Out:
#                       business zip code  \
# 0                        Shell    92101
# 1                        Shell    92123
# 2          Texas Street Valero    92116
# 3                      Chevron    92117
# 4  Laurel Pacific Gas (Valero)    92101
#
#                                           address gas1 currency gas1 type  \
# 0                  1011 A St, San Diego, CA 92101           USD   Regular
# 1      2777 Health Center Dr, San Diego, CA 92123           USD   Regular
# 2              4616 Texas St, San Diego, CA 92116           USD   Regular
# 3  7070 Clairemont Mesa Blvd, San Diego, CA 92117           USD   Regular
# 4           2499 Pacific Hwy, San Diego, CA 92101           USD   Regular
#
#    gas1 price gas1 pricetag gas1 unit              gas1 updated gas2 currency  \
# 0         7.0         $7.00    gallon  2023-10-03T09:20:18.000Z           USD
# 1         7.0         $7.00    gallon  2023-10-02T15:59:32.000Z           USD
# 2         6.4         $6.40    gallon  2023-10-03T05:53:19.000Z           USD
# 3         6.3         $6.30    gallon  2023-10-03T09:15:59.000Z           USD
# 4         6.8         $6.80    gallon  2023-10-03T09:17:23.000Z           USD
#
#    ... gas2 price  gas2 pricetag gas2 unit              gas2 updated  \
# 0  ...       7.11          $7.11    gallon  2023-10-02T19:38:42.000Z
# 1  ...       7.20          $7.20    gallon  2023-10-02T19:28:22.000Z
# 2  ...       6.60          $6.60    gallon  2023-10-03T05:53:19.000Z
# 3  ...       6.50          $6.50    gallon  2023-10-03T09:15:59.000Z
# 4  ...       6.90          $6.90    gallon  2023-10-02T05:37:50.000Z
#
#   gas3 currency gas3 type gas3 price  gas3 pricetag gas3 unit  \
# 0           USD   Premium        7.2          $7.20    gallon
# 1           USD   Premium        7.3          $7.30    gallon
# 2           USD   Premium        6.8          $6.80    gallon
# 3           USD   Premium        6.6          $6.60    gallon
# 4           USD   Premium        7.0          $7.00    gallon
#
#                gas3 updated
# 0  2023-10-02T13:26:42.000Z
# 1  2023-10-02T19:28:22.000Z
# 2  2023-10-03T05:53:19.000Z
# 3  2023-10-03T09:15:59.000Z
# 4  2023-10-02T10:00:45.000Z
#
# [5 rows x 21 columns]

# %%
cleaned_gas_df.count()
# Out:
# business         151
# zip code         151
# address          151
# gas1 currency    133
# gas1 type        133
# gas1 price       133
# gas1 pricetag    133
# gas1 unit        133
# gas1 updated     133
# gas2 currency    133
# gas2 type        133
# gas2 price       133
# gas2 pricetag    133
# gas2 unit        133
# gas2 updated     133
# gas3 currency    133
# gas3 type        133
# gas3 price       133
# gas3 pricetag    133
# gas3 unit        133
# gas3 updated     133
# dtype: int64

# %%
extra_clean_gas = cleaned_gas_df.dropna()
extra_clean_gas.count()
# Out:
# business         133
# zip code         133
# address          133
# gas1 currency    133
# gas1 type        133
# gas1 price       133
# gas1 pricetag    133
# gas1 unit        133
# gas1 updated     133
# gas2 currency    133
# gas2 type        133
# gas2 price       133
# gas2 pricetag    133
# gas2 unit        133
# gas2 updated     133
# gas3 currency    133
# gas3 type        133
# gas3 price       133
# gas3 pricetag    133
# gas3 unit        133
# gas3 updated     133
# dtype: int64

# %%
print(extra_clean_gas['gas1 currency'].unique())
print(extra_clean_gas['gas1 type'].unique())
print(extra_clean_gas['gas1 unit'].unique())
print(extra_clean_gas['gas2 currency'].unique())
print(extra_clean_gas['gas2 type'].unique())
print(extra_clean_gas['gas2 unit'].unique())
print(extra_clean_gas['gas3 currency'].unique())
print(extra_clean_gas['gas3 type'].unique())
print(extra_clean_gas['gas3 unit'].unique())
# Out:
# ['USD']
# ['Regular']
# ['gallon']
# ['USD']
# ['Midgrade']
# ['gallon']
# ['USD']
# ['Premium']
# ['gallon']

# %%
# Gas

# %%
# Read in CSV and clean data
SD_median_income = pd.read_csv("Resources/Household Income Median.csv")
SD_median_income = SD_median_income.rename(columns={'Zip':'zip code'})
SD_median_income = SD_median_income.dropna()
SD_median_income.head()
# Out:
#   zip code  Household Income Median
# 0    92014                 155531.0
# 1    92025                  58273.0
# 2    92027                  65989.0
# 3    92037                 109194.0
# 4    92071                  87334.0

# %%
# Find unique number of zipcodes in income dataset
SD_median_income['zip code'].unique()
# Out:
# array(['92014', '92025', '92027', '92037', '92071', '92101', '92102',
#        '92103', '92104', '92105', '92106', '92107', '92108', '92109',
#        '92110', '92111', '92113', '92114', '92115', '92116', '92117',
#        '92119', '92120', '92121', '92122', '92123', '92124', '92126',
#        '92127', '92128', '92129', '92130', '92131', '92139', '92145',
#        '92154', '92173'], dtype=object)

# %%
# Find unique number of zipcodes in gas dataset
extra_clean_gas['zip code'].unique().size
# Out:
# 30

# %%
# Calculate average gas prices per zip code
averaged_gas1_prices = extra_clean_gas.groupby(["zip code"])["gas1 price"].mean()
averaged_gas2_prices = extra_clean_gas.groupby(["zip code"])["gas2 price"].mean()
averaged_gas3_prices = extra_clean_gas.groupby(["zip code"])["gas3 price"].mean()

# %%
# Create df with avg gas prices per zip
gas_price_per_zip_avg = pd.DataFrame(
    {
        "Regular avg": averaged_gas1_prices,
        "Midgrade avg": averaged_gas2_prices,
        "Premium avg": averaged_gas3_prices,
    }
)
gas_price_per_zip_avg.head()
# Out:
#           Regular avg  Midgrade avg  Premium avg
# zip code
# 92101        6.685714      6.858571     6.957143
# 92102        6.333333      6.533333     6.683333
# 92103        6.540000      6.760000     6.920000
# 92104        6.365556      6.560000     6.747778
# 92105        6.283333      6.435000     6.688333

# %%
# Load in csv with lat, long, population, density
zip_df = pd.read_csv("Resources/uszips.csv")
sd_zip_df_unclean = zip_df.loc[zip_df["county_names_all"] == "San Diego", :]
sd_zip_df_unclean = sd_zip_df_unclean.rename(columns={'zip':'zip code'})
# Create df of only info we want
sd_zip_df = sd_zip_df_unclean[['zip code', 'lat', 'lng', 'city', 'population', 'density']]
sd_zip_df = pd.DataFrame(sd_zip_df)

len(sd_zip_df)
# Out:
# 112

# %%
# # Making sure zip in all dfs are string types
# sd_zip_df['zip code'] = sd_zip_df['zip code'].astype(int)
# gas_price_per_zip_avg['zip code'] = gas_price_per_zip_avg['zip code'].astype(int)
# SD_median_income['zip code'] = SD_median_income['zip code'].astype(int)

# %%
df = sd_zip_df.loc[['92014', '92025', '92027', '92037', '92071', '92101', '92102',
       '92103', '92104', '92105', '92106', '92107', '92108', '92109',
       '92110', '92111', '92113', '92114', '92115', '92116', '92117',
       '92119', '92120', '92121', '92122', '92123', '92124', '92126',
       '92127', '92128', '92129', '92130', '92131', '92139', '92145',
       '92154', '92173']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\UCSD\class_files\7\Project1\gas_prices_zip_code.ipynb Cell 21 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/UCSD/class_files/7/Project1/gas_prices_zip_code.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> df = sd_zip_df.loc[['92014', '92025', '92027', '92037', '92071', '92101', '92102',
#       <a href='vscode-notebook-cell:/d%3A/UCSD/class_files/7/Project1/gas_prices_zip_code.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a>        '92103', '92104', '92105', '92106', '92107', '92108', '92109',
#       <a href='vscode-notebook-cell:/d%3A/UCSD/class_files/7/Project1/gas_prices_zip_code.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a>        '92110', '92111', '92113', '92114', '92115', '92116', '92117',
#       <a href='vscode-notebook-cell:/d%3A/UCSD/class_files/7/Project1/gas_prices_zip_code.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a>        '92119', '92120', '92121', '92122', '92123', '92124', '92126',
#       <a href='vscode-notebook-cell:/d%3A/UCSD/class_files/7/Project1/gas_prices_zip_code.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a>        '92127', '92128', '92129', '92130', '92131', '92139', '92145',
#       <a href='vscode-notebook-cell:/d%3A/UCSD/class_files/7/Project1/gas_prices_zip_code.ipynb#X26sZmlsZQ%3D%3D?line=5'>6</a>        '92154', '92173']]
#
# File c:\Users\noell\anaconda3\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\noell\anaconda3\Lib\site-packages\pandas\core\indexing.py:1332, in _LocIndexer._getitem_axis(self, key, axis)
#    1329     if hasattr(key, "ndim") and key.ndim > 1:
#    1330         raise ValueError("Cannot index with multidimensional key")
# -> 1332     return self._getitem_iterable(key, axis=axis)
#    1334 # nested tuple slicing
#    1335 if is_nested_tuple(key, labels):
#
# File c:\Users\noell\anaconda3\Lib\site-packages\pandas\core\indexing.py:1272, in _LocIndexer._getitem_iterable(self, key, axis)
#    1269 self._validate_key(key, axis)
#    1271 # A collection of keys
# -> 1272 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1273 return self.obj._reindex_with_indexers(
#    1274     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1275 )
#
# File c:\Users\noell\anaconda3\Lib\site-packages\pandas\core\indexing.py:1462, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1459 ax = self.obj._get_axis(axis)
#    1460 axis_name = self.obj._get_axis_name(axis)
# -> 1462 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1464 return keyarr, indexer
#
# File c:\Users\noell\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File c:\Users\noell\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5936     if use_interval_msg:
#    5937         key = list(key)
# -> 5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['92014', '92025', '92027', '92037', '92071', '92101', '92102', '92103',\n       '92104', '92105', '92106', '92107', '92108', '92109', '92110', '92111',\n       '92113', '92114', '92115', '92116', '92117', '92119', '92120', '92121',\n       '92122', '92123', '92124', '92126', '92127', '92128', '92129', '92130',\n       '92131', '92139', '92145', '92154', '92173'],\n      dtype='object')] are in the [index]"

# %%
merg_zip_data = sd_zip_df.merge(gas_price_per_zip_avg, on=['zip code'], how='right')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\UCSD\class_files\7\Project1\gas_prices_zip_code.ipynb Cell 21 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/UCSD/class_files/7/Project1/gas_prices_zip_code.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> merg_zip_data = sd_zip_df.merge(gas_price_per_zip_avg, on=['zip code'], how='right')
#
# File c:\Users\noell\anaconda3\Lib\site-packages\pandas\core\frame.py:9843, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9824 @Substitution("")
#    9825 @Appender(_merge_doc, indents=2)
#    9826 def merge(
#    (...)
#    9839     validate: str | None = None,
#    9840 ) -> DataFrame:
#    9841     from pandas.core.reshape.merge import merge
# -> 9843     return merge(
#    9844         self,
#    9845         right,
#    9846         how=how,
#    9847         on=on,
#    9848         left_on=left_on,
#    9849         right_on=right_on,
#    9850         left_index=left_index,
#    9851         right_index=right_index,
#    9852         sort=sort,
#    9853         suffixes=suffixes,
#    9854         copy=copy,
#    9855         indicator=indicator,
#    9856         validate=validate,
#    9857     )
#
# File c:\Users\noell\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:148, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     131 @Substitution("\nleft : DataFrame or named Series")
#     132 @Appender(_merge_doc, indents=0)
#     133 def merge(
#    (...)
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
#     151         how=how,
#     152         on=on,
#     153         left_on=left_on,
#     154         right_on=right_on,
#     155         left_index=left_index,
#     156         right_index=right_index,
#     157         sort=sort,
#     158         suffixes=suffixes,
#     159         indicator=indicator,
#     160         validate=validate,
#     161     )
#     162     return op.get_result(copy=copy)
#
# File c:\Users\noell\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:741, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     733 (
#     734     self.left_join_keys,
#     735     self.right_join_keys,
#     736     self.join_names,
#     737 ) = self._get_merge_keys()
#     739 # validate the merge keys dtypes. We may need to coerce
#     740 # to avoid incompatible dtypes
# --> 741 self._maybe_coerce_merge_keys()
#     743 # If argument passed to validate,
#     744 # check if columns specified as unique
#     745 # are in fact unique.
#     746 if validate is not None:
#
# File c:\Users\noell\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:1401, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1395     # unless we are merging non-string-like with string-like
#    1396     elif (
#    1397         inferred_left in string_types and inferred_right not in string_types
#    1398     ) or (
#    1399         inferred_right in string_types and inferred_left not in string_types
#    1400     ):
# -> 1401         raise ValueError(msg)
#    1403 # datetimelikes must match exactly
#    1404 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on int64 and object columns. If you wish to proceed you should use pd.concat
